# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})

# %%
fig = plt.figure(dpi=600)
hfont = {'fontname':'Garamond'}
ax1 = fig.add_subplot(111)
ax1 = plt.quiver([0, 0], [0, 0], [5, 3], [1, 4], angles='xy', scale_units='xy', scale=1)
plt.xlim(-2, 5)
plt.ylim(-2, 5)
plt.grid(visible=True, color="grey", zorder=-1.0)
plt.title(r"cos($\theta$) = 0.745", fontsize=15)
# Out:
# Text(0.5, 1.0, 'cos($\\theta$) = 0.745')
