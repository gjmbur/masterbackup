# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

# %%
fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection='3d')

x = np.arange(-10, 10.1, 1)
y = np.arange(-10, 10.1, 1)

X, Y = np.meshgrid(x, y)
Z = (-X**2) + (-Y**2)

surf = ax.plot_surface(X, Y, Z, cmap = plt.cm.cividis)

ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)

fig.colorbar(surf, shrink=0.5, aspect=8)

plt.show()

# %%
# https://stackoverflow.com/questions/60164477/define-gradient-and-hessian-function-in-python/60165226#60165226
from sympy.abc import x, y
from sympy import symbols, ordered, Matrix, hessian
v = list(ordered(Z.free_symbols)); v
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/r1/v24t28293vb4sxbzx6539ddw0000gn/T/ipykernel_664/1714717656.py in <module>
#       1 from sympy.abc import x, y
#       2 from sympy import symbols, ordered, Matrix, hessian
# ----> 3 v = list(ordered(Z.free_symbols)); v
#
# AttributeError: 'numpy.ndarray' object has no attribute 'free_symbols'
