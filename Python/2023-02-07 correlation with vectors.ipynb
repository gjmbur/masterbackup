# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
home = "/Users/griffinjmbur/"

# %%
# Let's set a better font
from matplotlib import rc
rc("font", **{"family":"serif", "serif":["Times"]})

# %%
sns.set_style("whitegrid")

# %%
fig = plt.figure(dpi=600)
ax = plt.quiver([0,0], [0, 0], [5, 4], [12, 3], color="red", angles="xy", scale_units="xy", scale=1)
plt.xlim(-2, 8)
plt.ylim(-2, 15)
plt.grid(visible=True, color="black", zorder = 3.0)
plt.xticks(np.arange(-2, 8, step=1.0))
plt.yticks(np.arange(-2, 15, step=1.0))
plt.text(3.5, 11.5, "X2", c="red")
plt.text(3.5, 1.5, "X1", c="red")
plt.xlabel("Subject 1")
plt.ylabel("Subject 2")
plt.title("Correlation as the cosine of the angle between two centered vectors")
plt.savefig(f"{home}desktop/Python/correlation_with_vectors")
